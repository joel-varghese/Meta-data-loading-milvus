# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd() if (Path.cwd() / "shared").exists() else Path.cwd().parent

df = pd.read_csv(ROOT / "data" / "final_data.csv")

new_df = df[:100]

new_df.to_csv(ROOT / "data" / "process.csv", index=False)
